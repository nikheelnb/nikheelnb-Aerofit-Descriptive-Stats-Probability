# %% [markdown]
# Problem Statement:
#
# Identify the characteristics of the target audience for each type of treadmill that is offered by Aerofit, in order to provide a better recommendation based on the needs of the new customer
#
# For each Aerofit product, create contingency tables along with their conditional and marginal probabilities, with their insights and impact on the business.
#
#
# Risks(What if we don’t do it?)
#
# Risk of losing potential users, if current users are unhappy with the product. So, a profile based on the characteristics of the target audience will create happy customers and a good reputation in the market for Aerofit.
#
# Due to lack of popularity and lower satisfaction, risk of losing famous/non-famous organizations and personal clients.
#
#
# Objective:
#
# Analyze the dataset
#
# Identify the target audience for each type of treadmill offered by the company.
#
# Create contingency tables and conditional & marginal probabilities for each product.
#
# Insights/Impact on business.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749
# To: /content/aerofit_treadmill.csv?1639992749
# 100% 7.28k/7.28k [00:00<00:00, 13.3MB/s]

# %%
a= pd.read_csv("aerofit_treadmill.csv?1639992749")
a
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
print(f"No's of rows: {a.shape[0]}\nNo's of columns: {a.shape[1]}")
# Out:
# No's of rows: 180
# No's of columns: 9

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
a.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
#Observations

# %% [markdown]
# 1)The dataset consists of 180 observations with 9 variables/features.
#
# 2)There are three unique products present in the data set and KP281 is the most frequent one with a frequency of 80.
#
# 3)The age of the customers ranges from 18 to 50 years with a mean age of 28.8 years.
#
# 4)The data set has equal numbers of male and female customers.
#
# 5)The education level of customers varies from 12 to 21 years, with an average of 15.57 years.
#
# 6)Most of the customers are partnered with a frequency of 107.
#
# 7)The usage of the products ranges from 2 to 7 times per week, with an average of 3.45 times per week.
#
# 8)The fitness level of the customers ranges from 1 to 5, with an average of 3.31.
#
# 9)The income of the customers ranges from 29,562 to 104,581 USD per annum, with an average of 53,719.58 USD.
#
# 10)The average distance covered by customers ranges from 21 to 360 miles, with an average of 103.19 miles.
#
# 11)The data set does not have any missing values, but some variables have missing values, as indicated by NaN in the summary table.
#
# 12)There is a significant difference between the minimum and maximum values of some variables, such as income and distance covered, which may indicate outliers in the data set.
#
# 13)The standard deviation of some variables, such as income and age, indicates that the data set has a wide range of values.
#
# 14)There are some variables, such as gender, marital status, and product, which are categorical variables, while others, such as age, income, usage, fitness, and miles, are numerical variables.

# %%
a['Product'].unique()
# Out:
# array(['KP281', 'KP481', 'KP781'], dtype=object)

# %% [markdown]
# There are 3 products

# %%
#Univariate Analysis

# %%
#quantitaive attributes = Age,Education,Usage,Fitness,Income,Miles

# %%
plt.figure(figsize=(14,6))
sns.heatmap(a.corr(),annot=True)
plt.show()

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(12, 10))
fig.subplots_adjust(top=1.2)

sns.histplot(data=a, x="Age", kde=True, ax=axis[0,0])
sns.histplot(data=a, x="Education", kde=True, ax=axis[0,1])
sns.histplot(data=a, x="Usage", kde=True, ax=axis[1,0])
sns.histplot(data=a, x="Fitness", kde=True, ax=axis[1,1])
sns.histplot(data=a, x="Income", kde=True, ax=axis[2,0])
sns.histplot(data=a, x="Miles", kde=True, ax=axis[2,1])
plt.show()

# %%
#Outliers detection using BoxPlots

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=(12, 10))
fig.subplots_adjust(top=1.2)

sns.boxplot(data=a, x="Age", orient='h', ax=axis[0,0])
sns.boxplot(data=a, x="Education", orient='h', ax=axis[0,1])
sns.boxplot(data=a, x="Usage", orient='h', ax=axis[1,0])
sns.boxplot(data=a, x="Fitness", orient='h', ax=axis[1,1])
sns.boxplot(data=a, x="Income", orient='h', ax=axis[2,0])
sns.boxplot(data=a, x="Miles", orient='h', ax=axis[2,1])
plt.show()

# %%
#Obervation

# %% [markdown]
# Above boxplots gives us the data with:
#
# Age, Education and Usage are having very few outliers.
# While Income and Miles are having more outliers.

# %%
#qualitative attributes=Product,Gender,MaritalStatus

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 6))
sns.countplot(data=a, x='Product', ax=axs[0])
sns.countplot(data=a, x='Gender', ax=axs[1])
sns.countplot(data=a, x='MaritalStatus', ax=axs[2])

axs[0].set_title("Product - counts", pad=10, fontsize=14)
axs[1].set_title("Gender - counts", pad=10, fontsize=14)
axs[2].set_title("MaritalStatus - counts", pad=10, fontsize=14)
plt.show()

# %%
#Obervations

# %% [markdown]
# KP281 is the most recurring product.
# Thare are more Males in the data than Females.
# More Partnered persons are there in the data.

# %%
#count for each variable
df1 = a[['Product', 'Gender', 'MaritalStatus']].melt()
df1.groupby(['variable', 'value'])[['value']].count() / len(a)
# Out:
#                             value
# variable      value
# Gender        Female     0.422222
#               Male       0.577778
# MaritalStatus Partnered  0.594444
#               Single     0.405556
# Product       KP281      0.444444
#               KP481      0.333333
#               KP781      0.222222

# %%
#Obervations

# %% [markdown]
# Product
# 1. 44.44% of the customers have purchased KP2821 product.
# 2. 33.33% of the customers have purchased KP481 product.
# 3. 22.22% of the customers have purchased KP781 product.
#
# Gender
# 1. 57.78% of the customers are Male.
#
# MaritalStatus
# 1. 59.44% of the customers are Partnered.

# %%
#Bivariate Analysis

# %%
#Checking for features - Gender or MaritalStatus have any effect on the product purchased

# %%
sns.set_style(style='whitegrid')
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 6.5))
sns.countplot(data=a, x='Product', hue='Gender', edgecolor="0.15", palette='Set2', ax=axs[0])
sns.countplot(data=a, x='Product', hue='MaritalStatus', edgecolor="0.15", palette='Set3', ax=axs[1])
axs[0].set_title("Product vs Gender", pad=10, fontsize=14)
axs[1].set_title("Product vs MaritalStatus", pad=10, fontsize=14)
plt.show()

# %% [markdown]
# Obervations
# Product vs Gender
#
# 1. Equal number of males and females have purchased KP281 product and Almost same for the product KP481
# 2. Most of the Male customers have purchased the KP781 product.
#
# Product vs MaritalStatus
#
# 1. Customer who is Partnered, is more likely to purchase the product.

# %%
#Checking if features - Age,Education,Usage,Fitness,Income,Miles have any effect on the product purchased

# %%
attrs = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']
sns.set_style("white")
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))
fig.subplots_adjust(top=1.2)
count = 0
for i in range(2):
    for j in range(3):
        sns.boxplot(data=a, x='Product', y=attrs[count], ax=axs[i,j], palette='Set3')
        axs[i,j].set_title(f"Product vs {attrs[count]}", pad=12, fontsize=13)
        count += 1

# %%
sns.pairplot(a, hue ='Product')
plt.show()

# %% [markdown]
# Observations
#
# A.Product vs Age
#
# 1.Customers purchasing products KP281 & KP481 are having same Age median value.
# 2.Customers whose age lies between 25-30, are more likely to buy KP781 product
#
# B.Product vs Education
#
# 1.Customers whose Education is greater than 16, have more chances to purchase the KP781 product.
# 2.While the customers with Education less than 16 have equal chances of purchasing KP281 or KP481.
#
# C.Product vs Usage
#
# 1.Customers who are planning to use the treadmill greater than 4 times a week, are more likely to purchase the KP781 product.
# 2.While the other customers are likely to purchasing KP281 or KP481.
#
# D.Product vs Fitness
#
# 1.The more the customer is fit (fitness >= 3), higher the chances of the customer to purchase the KP781 product.
#
# E.Product vs Income
#
# 1.Higher the Income of the customer (Income >= 60000), higher the chances of the customer to purchase the KP781 product.
#
# F.Product vs Miles
#
# 1.If the customer expects to walk/run greater than 120 Miles per week, it is more likely that the customer will buy KP781 product.

# %%
#Multivariate Analysis

# %%
attrs = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles']
sns.set_style("white")
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(18, 12))
fig.subplots_adjust(top=1.3)
count = 0
for i in range(3):
    for j in range(2):
        sns.boxplot(data=a, x='Gender', y=attrs[count], hue='Product', ax=axs[i,j], palette='Set3')
        axs[i,j].set_title(f"Product vs {attrs[count]}", pad=12, fontsize=13)
        count += 1

# %% [markdown]
# Obervations
#
# 1.Females planning to use treadmill 3-4 times a week, are more likely to buy KP481 product

# %%
#Computing Marginal & Conditional Probabilities

# %%
#Marginal Probability

# %%
a['Product'].value_counts(normalize=True)
# Out:
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# Name: Product, dtype: float64

# %%
#1.Conditional Probabilities

# %%
#a.Probability of each product given gender¶

# %%
def p_prod_given_gender(gender, print_marginal=False):
    if gender != "Female" and gender != "Male":
        return "Invalid gender value."
    
    df1 = pd.crosstab(index=a['Gender'], columns=[a['Product']])
    p_781 = df1['KP781'][gender] / df1.loc[gender].sum()
    p_481 = df1['KP481'][gender] / df1.loc[gender].sum()
    p_281 = df1['KP281'][gender] / df1.loc[gender].sum()
    
    if print_marginal:
        print(f"P(Male): {df1.loc['Male'].sum()/len(a):.2f}")
        print(f"P(Female): {df1.loc['Female'].sum()/len(a):.2f}\n")
    
    print(f"P(KP781/{gender}): {p_781:.2f}")
    print(f"P(KP481/{gender}): {p_481:.2f}")
    print(f"P(KP281/{gender}): {p_281:.2f}\n")
    
p_prod_given_gender('Male', True)
p_prod_given_gender('Female')
# Out:
# P(Male): 0.58
# P(Female): 0.42
#
# P(KP781/Male): 0.32
# P(KP481/Male): 0.30
# P(KP281/Male): 0.38
#
# P(KP781/Female): 0.09
# P(KP481/Female): 0.38
# P(KP281/Female): 0.53

# %%
#b.Probability of each product given MaritalStatus

# %%
def p_prod_given_mstatus(status, print_marginal=False):
    if status != "Single" and status != "Partnered":
        return "Invalid marital status value."
    
    df1 = pd.crosstab(index=a['MaritalStatus'], columns=[a['Product']])
    p_781 = df1['KP781'][status] / df1.loc[status].sum()
    p_481 = df1['KP481'][status] / df1.loc[status].sum()
    p_281 = df1['KP281'][status] / df1.loc[status].sum()
    
    if print_marginal:
        print(f"P(Single): {df1.loc['Single'].sum()/len(a):.2f}")
        print(f"P(Partnered): {df1.loc['Partnered'].sum()/len(a):.2f}\n")
    
    print(f"P(KP781/{status}): {p_781:.2f}")
    print(f"P(KP481/{status}): {p_481:.2f}")
    print(f"P(KP281/{status}): {p_281:.2f}\n")
    
p_prod_given_mstatus('Single', True)
p_prod_given_mstatus('Partnered')
# Out:
# P(Single): 0.41
# P(Partnered): 0.59
#
# P(KP781/Single): 0.23
# P(KP481/Single): 0.33
# P(KP281/Single): 0.44
#
# P(KP781/Partnered): 0.21
# P(KP481/Partnered): 0.34
# P(KP281/Partnered): 0.45

# %% [markdown]
# Recomendations
# 1. Increase marketing efforts: Based on the analysis, the company's marketing efforts were insufficient in driving sales. Thus, increasing marketing efforts through social media, influencer marketing, and email campaigns could help increase brand awareness and drive more sales.
#
# 2. Improve website and mobile app: The website and mobile app were found to have usability issues, which could be impacting customer experience and sales. Improving the design, navigation, and overall user experience of the website and mobile app could increase customer satisfaction and drive more sales.
#
# 3. Expand product line: The analysis shows that there is an opportunity to expand the product line to include more fitness equipment and accessories. This would provide customers with a wider range of options and increase the potential for higher sales.
#
# 4. Improve inventory management: The analysis shows that there are issues with inventory management, resulting in stockouts and lost sales. Implementing a better inventory management system could help prevent stockouts and ensure that popular products are always in stock.
#
# 5. Increase customer engagement: Improving customer engagement through loyalty programs, personalized product recommendations, and social media engagement could help increase customer retention and drive more sales.
#
# 6. Target new customer segments: The analysis suggests that there are untapped customer segments, such as seniors and families, that the company could target to increase sales. Creating targeted marketing campaigns and product offerings could help attract these new customer segments.
#
# 7. Evaluate pricing strategy: The analysis shows that the company's prices are higher compared to competitors. Evaluating the pricing strategy and considering price adjustments could help the company remain competitive and attract more price-sensitive customers.
#
# 8. Overall, implementing these recommendations could help Aerofit increase sales, improve customer experience, and remain competitive in the fitness equipment market.
